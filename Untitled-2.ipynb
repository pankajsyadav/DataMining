# %%
# !conda install MikTeX
# Out:
# Error while loading conda entry point: conda-libmamba-solver (module 'libmambapy' has no attribute 'QueryFormat')
#
# CondaValueError: You have chosen a non-default solver backend (libmamba) but it was not recognized. Choose one of: classic

# %%
# Export Notebook to PDF

**Method 1: Via HTML (No LaTeX needed)**
1. First save this notebook with a name
2. Run the command below in a terminal to export to HTML
3. Then open the HTML and print to PDF from your browser

Command:
```
jupyter nbconvert --to html "notebook-name.ipynb"
```

**Method 2: Install MikTeX manually**
1. Download from: https://miktex.org/download
2. Run the installer
3. After installation, use: `jupyter nbconvert --to pdf "notebook-name.ipynb"`

**Method 3: Use VS Code's export feature**
- Click the "..." in the notebook toolbar
- Select Export → PDF (or HTML)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement MikTeX (from versions: none)
# ERROR: No matching distribution found for MikTeX
